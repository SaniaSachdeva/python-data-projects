# %%
import requests

response = requests.get("http://127.0.0.1:5000/performance/sample")
print(response.json())
# Out:
# {'Hours_Studied': 23, 'Attendance': 84, 'Parental_Involvement': 0, 'Access_to_Resources': 2, 'Extracurricular_Activities': 0, 'Sleep_Hours': 7, 'Previous_Scores': 73, 'Motivation_Level': 0, 'Internet_Access': 1, 'Tutoring_Sessions': 0, 'Family_Income': 0, 'Teacher_Quality': 1, 'School_Type': 0, 'Peer_Influence': 2, 'Physical_Activity': 3, 'Learning_Disabilities': 0, 'Parental_Education_Level': 0, 'Distance_from_Home': 0, 'Gender': 0}

# %%
import requests

response = requests.get("http://127.0.0.1:5000/performance/explain")
print(response.text)
# Out:
# This web service predicts a student’s exam score using different parts of their academic life, study habits, and environment.
#
# When you send data to the model, you include information such as how many hours the student studies, their attendance percentage, and their previous exam scores. Some fields use numbers instead of words — for example, parental involvement, access to resources, and motivation are encoded as 0 for low, 1 for medium, and 2 for high.
#
# Other factors, such as extracurricular activities, internet access, and learning disabilities, are simple yes-or-no values represented as 0 or 1.
#
# Habits like sleep hours, physical activity, and tutoring sessions are included as numeric values. Family background is represented through income level and parental education, while school-related aspects like teacher quality, school type, peer influence, and distance from home are also provided as numerical codes.
#
# Gender is encoded as 0 for male and 1 for female.
#
# ...

# %%
test1 = {
    "Hours_Studied": 10,
    "Attendance": 95,
    "Parental_Involvement": 2,
    "Access_to_Resources": 2,
    "Extracurricular_Activities": 1,
    "Sleep_Hours": 8,
    "Previous_Scores": 85,
    "Motivation_Level": 2,
    "Internet_Access": 1,
    "Tutoring_Sessions": 2,
    "Family_Income": 2,
    "Teacher_Quality": 2,
    "School_Type": 1,
    "Peer_Influence": 2,
    "Physical_Activity": 3,
    "Learning_Disabilities": 0,
    "Parental_Education_Level": 2,
    "Distance_from_Home": 1,
    "Gender": 0
}

response = requests.post("http://127.0.0.1:5000/performance/evaluate", json=test1)
print("Test 1 Result:", response.json())
# Out:
# Test 1 Result: 72.80807099128347

# %%
test2 = {
    "Hours_Studied": 20,
    "Attendance": 98,
    "Parental_Involvement": 2,
    "Access_to_Resources": 2,
    "Extracurricular_Activities": 1,
    "Sleep_Hours": 8,
    "Previous_Scores": 85,
    "Motivation_Level": 2,
    "Internet_Access": 1,
    "Tutoring_Sessions": 2,
    "Family_Income": 2,
    "Teacher_Quality": 2,
    "School_Type": 0,
    "Peer_Influence": 3,
    "Physical_Activity": 3,
    "Learning_Disabilities": 0,
    "Parental_Education_Level": 2,
    "Distance_from_Home": 1,
    "Gender": 1
}

response = requests.post("http://127.0.0.1:5000/performance/evaluate", json=test2)
print("Test 2 Result:", response.json())
# Out:
# Test 2 Result: 76.94054670304433

# %%
test3 = {
    "Hours_Studied": 20,
    "Attendance": 85,
    "Parental_Involvement": 2,
    "Access_to_Resources": 2,
    "Extracurricular_Activities": 1,
    "Sleep_Hours": 10,
    "Previous_Scores": 95,
    "Motivation_Level": 2,
    "Internet_Access": 0,
    "Tutoring_Sessions": 2,
    "Family_Income": 2,
    "Teacher_Quality": 2,
    "School_Type": 0,
    "Peer_Influence": 0,
    "Physical_Activity": 3,
    "Learning_Disabilities": 0,
    "Parental_Education_Level": 2,
    "Distance_from_Home": 2,
    "Gender": 1
}

response = requests.post("http://127.0.0.1:5000/performance/evaluate", json=test3)
print("Test 3 Result:", response.json())
# Out:
# Test 3 Result: 71.91012245944233

# %%
test4 = {
    "Hours_Studied": 20,
    "Attendance": 25,
    "Parental_Involvement": 2,
    "Access_to_Resources": 2,
    "Extracurricular_Activities": 1,
    "Sleep_Hours": 10,
    "Previous_Scores": 100,
    "Motivation_Level": 2,
    "Internet_Access": 1,
    "Tutoring_Sessions": 2,
    "Family_Income": 2,
    "Teacher_Quality": 2,
    "School_Type": 0,
    "Peer_Influence": 0,
    "Physical_Activity": 3,
    "Learning_Disabilities": 0,
    "Parental_Education_Level": 2,
    "Distance_from_Home": 2,
    "Gender": 1
}

response = requests.post("http://127.0.0.1:5000/performance/evaluate", json=test4)
print("Test 4 Result:", response.json())
# Out:
# Test 4 Result: 61.06214050612711

# %%
test5 = {
    "Hours_Studied": 24,
    "Attendance": 99,
    "Parental_Involvement": 2,
    "Access_to_Resources": 2,
    "Extracurricular_Activities": 1,
    "Sleep_Hours": 8,
    "Previous_Scores": 100,
    "Motivation_Level": 2,
    "Internet_Access": 0,
    "Tutoring_Sessions": 2,
    "Family_Income": 2,
    "Teacher_Quality": 2,
    "School_Type": 0,
    "Peer_Influence": 2,
    "Physical_Activity": 5,
    "Learning_Disabilities": 0,
    "Parental_Education_Level": 2,
    "Distance_from_Home": 1,
    "Gender": 1
}

response = requests.post("http://127.0.0.1:5000/performance/evaluate", json=test5)
print("Test 5 Result:", response.json())
# Out:
# Test 5 Result: 78.10489184986878
